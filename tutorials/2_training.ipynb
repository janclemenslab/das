# %% [markdown]
# # Training
# Train the network using `dss.train`. The function will:
# - load train/val/test data
# - initialize the network (and save to `_arch.yaml`)
# - save all parameters for reproducibility (to `_params.yaml`)
# - train the network and save the best network to disk (to `_model.h5`)
# - run inference and evaluate the network using the test data (to `_results.h5`).
#
# In the process, four files will be created, all starting with the date_time the process was started (`YYYYMMDD_HHMMSS` as in `20192310_091032`):
# - `*_params.yaml` - training parameters etc
# - `*_arch.yaml` - network architecture
# - `*_model.h5` -  model architecture and weights
# - `*_results.h5` - evaluation results
#
# Training can be invoked from within a script/notebook (see below) or from the command line (command line interface created by [defopt](https://defopt.readthedocs.io/en/stable/index.html)):
# ```shell
# python -m dss.train --data-dir dat/dmel_single_raw.npy --save-dir res --model-name tcn --kernel-size 16 --nb-filters 16 --nb-hist 512 --nb-epoch 20 -i
# ```
#
# The above example uses the dataset created by [1_prepare_data.ipynb](1_prepare_data.ipynb). Note that the training data set and the model parameters are chosen for demonstration purposes and do not yield state-of-the-art performance.
# However, training for 10 epochs should yield a reasonably good model and takes around 15 minutes on a GPU. Training will typically converge after ~80 epochs.

# %%
import dss.train
import logging
logging.basicConfig(level=logging.INFO)

# %%
help(dss.train.train)
# Out:
# Help on function train in module dss.train:
#
# train(*, data_dir: str, model_name: str = 'tcn', nb_filters: int = 16, kernel_size: int = 3, nb_conv: int = 3, nb_hist: int = 1024, batch_norm: bool = True, save_dir: str = './', verbose: int = 2, nb_stacks: int = 2, with_y_hist: bool = True, nb_epoch: int = 400, fraction_data: float = None, seed: int = None, ignore_boundaries: bool = False, x_suffix: str = '', y_suffix: str = '', nb_pre_conv: int = 0, learning_rate: float = None, reduce_lr: bool = False, reduce_lr_patience: int = 5, batch_level_subsampling: bool = False, tensorboard: bool = False, use_separable: List[bool] = False, pre_kernel_size: int = 3, pre_nb_filters: int = 16, pre_nb_conv: int = 2, save_prefix: str = None, log_messages: bool = False)
#     [summary]
#
#     Args:
#         model_name (str): [description]. Defaults to 'tcn_seq'.
#         nb_filters (int): [description]. Defaults to 16.
#         kernel_size (int): [description]. Defaults to 3.
#         nb_conv (int): [description]. Defaults to 3.
#         nb_hist (int): [description]. Defaults to 1024.
#         batch_norm (bool): [description]. Defaults to True.
#         data_dir (str): [description]. Defaults to '../dat.song'.
#         save_dir (str): [description]. Defaults to current directory ('./').
#         verbose (int): Verbosity of training output (0 - no output(?), 1 - progress bar, 2 - one line per epoch). Defaults to 2.
#         nb_stacks (int): [description]. Defaults to 2.
#         with_y_hist (bool): [description]. Defaults to True.
#         nb_epoch (int): Defaults to 400.
#         fraction_data (float): [description]. Defaults to 1.0.
#         seed (int): Seed for selecting random subsets of the data. Defaults to None (no seed).
#         ignore_boundaries (bool): [description]. Defaults to False.
#         x_suffix (str): ... Defaults to '' (will use 'x')
#         y_suffix (str): ... Defaults to '' (will use 'y')
#         nb_pre_conv (int): adds a frontend of N conv blocks (conv-relu-batchnorm-maxpool2) to the TCN - useful for reducing the sampling rate for USV. Defaults to 0 (no frontend).
#         learning_rate (float): learning rate of the model. Defaults to None (values set in the model def)
#         reduce_lr (bool): reduce learning rate on plateau
#         batch_level_subsampling (bool): if true fraction data will select random subset of shuffled batches, otherwise will select a continuous chunk of the recording
#         tensorboard (bool): whether to write tensorboard logs to save_dir Defaults to False.
#         use_separable: use separable convs in TCN. Defaults to False.
#         pre_nb_filters (int): [description]. Defaults to 16.
#         pre_kernel_size (int): [description]. Defaults to 3.
#         pre_nb_conv (int): [description]. Defaults to 3.
#         save_prefix (str): prepend to save file name. Defaults to ''.
#         log_messages (bool): sets logging level to INFO. Defaults to False (will follow existing settings).

# %% [markdown]
# Training can be invoked from within a script/notebook (see below) or from the command line (command line interface created by [defopt](https://defopt.readthedocs.io/en/stable/index.html)). For instance:
# ```shell
# python -m dss.train --data-dir dat/dmel_single_raw.npy --save-dir res --model-name tcn --kernel-size 16 --nb-filters 16 --nb-hist 512 --nb-epoch 20 -i
# ```

# %%
dss.train.train(model_name='tcn',  # see `dss.models` for valid model_names
                data_dir='dat/dmel_single_raw.npy', 
                save_dir='res',
                nb_hist=512,
                kernel_size=16,
                nb_filters=16,
                ignore_boundaries=True,
                verbose=1,
                nb_epoch=10)
# Out:
# ______________________________________________
# activation_1 (Activation)       (None, 512, 16)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512, 16)      0           activation_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 512, 16)      0           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 512, 16)      272         spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 512, 16)      0           add[0][0]
#                                                                  conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 512, 16)      4112        add_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 512, 16)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512, 16)      0           activation_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 512, 16)      0           lambda_2[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 512, 16)      272         spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 512, 16)      0           add_1[0][0]
#                                                                  conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 512, 16)      4112        add_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 512, 16)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 512, 16)      0           activation_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_3 (SpatialDro (None, 512, 16)      0           lambda_3[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 512, 16)      272         spatial_dropout1d_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 512, 16)      0           add_2[0][0]
#                                                                  conv1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 512, 16)      4112        add_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512, 16)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 512, 16)      0           activation_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_4 (SpatialDro (None, 512, 16)      0           lambda_4[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 512, 16)      272         spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 512, 16)      0           add_3[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 512, 16)      4112        add_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 512, 16)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 512, 16)      0           activation_5[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_5 (SpatialDro (None, 512, 16)      0           lambda_5[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 512, 16)      272         spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 512, 16)      0           add_4[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 512, 16)      4112        add_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 512, 16)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 512, 16)      0           activation_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_6 (SpatialDro (None, 512, 16)      0           lambda_6[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 512, 16)      272         spatial_dropout1d_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 512, 16)      0           add_5[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 512, 16)      4112        add_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 512, 16)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 512, 16)      0           activation_7[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_7 (SpatialDro (None, 512, 16)      0           lambda_7[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 512, 16)      272         spatial_dropout1d_7[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 512, 16)      0           add_6[0][0]
#                                                                  conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 512, 16)      4112        add_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 512, 16)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 512, 16)      0           activation_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_8 (SpatialDro (None, 512, 16)      0           lambda_8[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 512, 16)      272         spatial_dropout1d_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 512, 16)      0           add_7[0][0]
#                                                                  conv1d_18[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 512, 16)      4112        add_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 512, 16)      0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 512, 16)      0           activation_9[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_9 (SpatialDro (None, 512, 16)      0           lambda_9[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 512, 16)      272         spatial_dropout1d_9[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 512, 16)      0           add_8[0][0]
#                                                                  conv1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 512, 16)      4112        add_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 512, 16)      0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 512, 16)      0           activation_10[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_10 (SpatialDr (None, 512, 16)      0           lambda_10[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 512, 16)      272         spatial_dropout1d_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 512, 16)      0           add_9[0][0]
#                                                                  conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 512, 16)      4112        add_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 512, 16)      0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 512, 16)      0           activation_11[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_11 (SpatialDr (None, 512, 16)      0           lambda_11[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 512, 16)      272         spatial_dropout1d_11[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 512, 16)      0           add_10[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 512, 16)      4112        add_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 512, 16)      0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 512, 16)      0           activation_12[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_12 (SpatialDr (None, 512, 16)      0           lambda_12[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 512, 16)      272         spatial_dropout1d_12[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 512, 16)      0           add_11[0][0]
#                                                                  conv1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 512, 16)      4112        add_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 512, 16)      0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 512, 16)      0           activation_13[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_13 (SpatialDr (None, 512, 16)      0           lambda_13[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 512, 16)      272         spatial_dropout1d_13[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 512, 16)      0           add_12[0][0]
#                                                                  conv1d_28[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 512, 16)      4112        add_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 512, 16)      0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 512, 16)      0           activation_14[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_14 (SpatialDr (None, 512, 16)      0           lambda_14[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 512, 16)      272         spatial_dropout1d_14[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 512, 16)      0           conv1d_2[0][0]
#                                                                  conv1d_4[0][0]
#                                                                  conv1d_6[0][0]
#                                                                  conv1d_8[0][0]
#                                                                  conv1d_10[0][0]
#                                                                  conv1d_12[0][0]
#                                                                  conv1d_14[0][0]
#                                                                  conv1d_16[0][0]
#                                                                  conv1d_18[0][0]
#                                                                  conv1d_20[0][0]
#                                                                  conv1d_22[0][0]
#                                                                  conv1d_24[0][0]
#                                                                  conv1d_26[0][0]
#                                                                  conv1d_28[0][0]
#                                                                  conv1d_30[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 512, 16)      0           add_15[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512, 2)       34          activation_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 512, 2)       0           dense[0][0]
# ==================================================================================================
# Total params: 65,826
# Trainable params: 65,826
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/10
#   82/1000 [=>............................] - ETA: 11:11 - loss: 0.2181
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-be9219785a2e> in <module>
#       7                 ignore_boundaries=True,
#       8                 verbose=1,
# ----> 9                 nb_epoch=10)
#
# /Volumes/shinkansen/Dropbox/code.py/deepss/src/dss/train.py in train(data_dir, model_name, nb_filters, kernel_size, nb_conv, nb_hist, batch_norm, save_dir, verbose, nb_stacks, with_y_hist, nb_epoch, fraction_data, seed, ignore_boundaries, x_suffix, y_suffix, nb_pre_conv, learning_rate, reduce_lr, reduce_lr_patience, batch_level_subsampling, tensorboard, use_separable, pre_kernel_size, pre_nb_filters, pre_nb_conv, save_prefix, log_messages)
#     178         verbose=verbose,
#     179         validation_data=val_gen,
# --> 180         callbacks=callbacks,
#     181     )
#     182
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_generator.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing)
#     601         shuffle=shuffle,
#     602         initial_epoch=initial_epoch,
# --> 603         steps_name='steps_per_epoch')
#     604
#     605   def evaluate(self,
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     263
#     264       is_deferred = not model._is_compiled
# --> 265       batch_outs = batch_function(*batch_data)
#     266       if not isinstance(batch_outs, list):
#     267         batch_outs = [batch_outs]
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1016       self._update_sample_weight_modes(sample_weights=sample_weights)
#    1017       self._make_train_function()
# -> 1018       outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1019
#    1020     if reset_metrics:
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3578
#    3579     fetched = self._callable_fn(*array_vals,
# -> 3580                                 run_metadata=self.run_metadata)
#    3581     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3582     output_structure = nest.pack_sequence_as(
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
