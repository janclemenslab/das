# %% [markdown]
# You may need to install keras-tuner for this to work.

# %%
import das.train_tune
tuner, model, params = das.train_tune.train(data_dir='tutorial_dataset.npy', save_dir='res', kernel_size=16, tune_config='tuning.yml')
